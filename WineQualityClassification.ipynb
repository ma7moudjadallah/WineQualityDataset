# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %%
wine_url = "https://raw.githubusercontent.com/ma7moudjadallah/WineQualityDataset/main/winequality-red.csv"
wine = pd.read_csv(wine_url , sep=';')
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
bins = [1, 3, 8, 10]    
group_names = ['bad', 'good','excellent']
wine['quality'] = pd.cut(wine['quality'], bins , labels = group_names) 
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4     good
# 1               7.8             0.880         0.00  ...       0.68      9.8     good
# 2               7.8             0.760         0.04  ...       0.65      9.8     good
# 3              11.2             0.280         0.56  ...       0.58      9.8     good
# 4               7.4             0.700         0.00  ...       0.56      9.4     good
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5     good
# 1595            5.9             0.550         0.10  ...       0.76     11.2     good
# 1596            6.3             0.510         0.13  ...       0.75     11.0     good
# 1597            5.9             0.645         0.12  ...       0.71     10.2     good
# ...

# %%
X = wine.iloc[:,:11]
y = wine['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
model = MLPClassifier(activation='relu',solver='adam',alpha=0.001)
model.fit(X_train, y_train)

expected_y  = ytest
predicted_y = model.predict(X_test)

print(metrics.accuracy_score(expected_y, predicted_y))
# Out:
# 0.9958333333333333

# %%
mlpc = MLPClassifier(hidden_layer_sizes=(11,2))
mlpc.fit(X_train, y_train)
pred_mlpc = mlpc.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
print(classification_report(ytest, pred_mlpc))
print(confusion_matrix(ytest, pred_mlpc))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.00      0.00      0.00         2
#         good       1.00      1.00      1.00       478
#
#     accuracy                           1.00       480
#    macro avg       0.50      0.50      0.50       480
# weighted avg       0.99      1.00      0.99       480
#
# [[  0   2]
#  [  0 478]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
